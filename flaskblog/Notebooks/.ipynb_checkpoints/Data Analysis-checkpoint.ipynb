# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = pd.read_csv('cars_engage_2022 (3).csv')

# %%
cars.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      NaN                 NaN
# ...

# %%
cars.drop(columns= 'Unnamed: 0', inplace = True)

# %%
cars['Ex-Showroom_Price'] = [i.replace('Rs. ','') for i in cars['Ex-Showroom_Price']]
cars['Ex-Showroom_Price'] = [i.replace(',','') for i in cars['Ex-Showroom_Price']]
cars['Ex-Showroom_Price'] = cars['Ex-Showroom_Price'].astype(int)

# %%
cars['Displacement'] = cars['Displacement'].astype(str)
cars['Displacement'] = [i.replace(' cc','') for i in cars['Displacement']]
cars.loc[cars['Displacement'].isna(),'Displacement'] = np.nan
cars['Displacement'] = cars['Displacement'].astype(float)

# %%
cars['Fuel_Tank_Capacity'] = cars['Fuel_Tank_Capacity'].astype(str)
cars['Fuel_Tank_Capacity'] = [i.replace('litres','') for i in cars['Fuel_Tank_Capacity']]
cars['Fuel_Tank_Capacity'] = cars['Fuel_Tank_Capacity'].astype(float)

# %%
cars['Height'] = cars['Height'].astype(str)
cars['Height'] = [i.replace('mm','') for i in cars['Height']]
cars['Height'] = cars['Height'].astype(float)
cars['Length'] = cars['Length'].astype(str)
cars['Length'] = [i.replace('mm','') for i in cars['Length']]
cars['Length'] = cars['Length'].astype(float)
cars['Width'] = cars['Width'].astype(str)
cars['Width'] = [i.replace('mm','') for i in cars['Width']]
cars['Width'] = cars['Width'].astype(float)

# %%
cars['City_Mileage'] = cars['City_Mileage'].astype(str)
cars['City_Mileage'] = [i.replace('km/litre','') for i in cars['City_Mileage']]
cars['City_Mileage'] = [i.replace('?','') for i in cars['City_Mileage']]
cars['City_Mileage'] = [i.replace(',','.') for i in cars['City_Mileage']]
cars['City_Mileage'] = [i.replace('12.5-12.7 ','12.6') for i in cars['City_Mileage']]
cars['City_Mileage'] = cars['City_Mileage'].astype(float)
cars['Highway_Mileage'] = cars['Highway_Mileage'].astype(str)
cars['Highway_Mileage'] = [i.replace('km/litre','') for i in cars['Highway_Mileage']]
cars['Highway_Mileage'] = [i.replace('8.3-8.4 ','8.4') for i in cars['Highway_Mileage']]
cars['Highway_Mileage'] = cars['Highway_Mileage'].astype(float)

# %%
cars['ARAI_Certified_Mileage'] = cars['ARAI_Certified_Mileage'].astype(str)
cars['ARAI_Certified_Mileage'] = [i.replace('km/litre','') for i in cars['ARAI_Certified_Mileage']]
cars['ARAI_Certified_Mileage'] = [i.replace('22.4-21.9 ','22') for i in cars['ARAI_Certified_Mileage']]
cars['ARAI_Certified_Mileage'] = [i.replace('9.8-10.0 ','10') for i in cars['ARAI_Certified_Mileage']]
cars['ARAI_Certified_Mileage'] = [i.replace('kmpl ','') for i in cars['ARAI_Certified_Mileage']]
cars['ARAI_Certified_Mileage'] = cars['ARAI_Certified_Mileage'].astype(float)
cars['ARAI_Certified_Mileage_for_CNG'] = cars['ARAI_Certified_Mileage_for_CNG'].astype(str)
cars['ARAI_Certified_Mileage_for_CNG'] = [i.replace('km/kg','') for i in cars['ARAI_Certified_Mileage_for_CNG']]
cars['ARAI_Certified_Mileage_for_CNG'] = cars['ARAI_Certified_Mileage_for_CNG'].astype(float)

# %%
cars['Kerb_Weight'] = cars['Kerb_Weight'].astype(str)
cars['Kerb_Weight'] = [i.replace('kg','') for i in cars['Kerb_Weight']]
cars['Kerb_Weight'] = [i.replace('1016-1043 ','1029') for i in cars['Kerb_Weight']]
cars['Kerb_Weight'] = [i.replace('1053-1080 ','1060') for i in cars['Kerb_Weight']]
cars['Kerb_Weight'] = cars['Kerb_Weight'].astype(float)

# %%
cars['Ground_Clearance'] = cars['Ground_Clearance'].astype(str)
cars['Ground_Clearance'] = [i.replace(' mm','') for i in cars['Ground_Clearance']]
cars['Ground_Clearance'] = cars['Ground_Clearance'].astype(float)
HP = cars.Power.str.extract(r'(\d{1,4}).*').astype(int) * 0.98632
cars.Power =HP

# %%
cars['Front_Track'] = cars['Front_Track'].astype(str)
cars['Front_Track'] = [i.replace(' mm','') for i in cars['Front_Track']]
cars['Front_Track'] = [i.replace(' (R13)','') for i in cars['Front_Track']]
cars['Front_Track'] = [i.replace(',','') for i in cars['Front_Track']]
cars['Front_Track'] = cars['Front_Track'].astype(float)
cars['Rear_Track'] = cars['Rear_Track'].astype(str)
cars['Rear_Track'] = [i.replace(' mm','') for i in cars['Rear_Track']]
cars['Rear_Track'] = [i.replace(' (R13)','') for i in cars['Rear_Track']]
cars['Rear_Track'] = [i.replace(',','') for i in cars['Rear_Track']]
cars['Rear_Track'] = cars['Rear_Track'].astype(float)

# %%
cars['Wheelbase'] = cars['Wheelbase'].astype(str)
cars['Wheelbase'] = [i.replace(' mm','') for i in cars['Wheelbase']]
cars['Wheelbase'] = cars['Wheelbase'].astype(float)

# %%
cars['City_Mileage'] = cars['City_Mileage'].fillna(cars['City_Mileage'].mean())
cars['Highway_Mileage'] = cars['Highway_Mileage'].fillna(cars['Highway_Mileage'].mean())
cars['ARAI_Certified_Mileage'] = cars['ARAI_Certified_Mileage'].fillna(cars['ARAI_Certified_Mileage'].mean())
cars['Kerb_Weight'] = cars['Kerb_Weight'].fillna(cars['Kerb_Weight'].mode())
cars['Length'] = cars['Length'].fillna(cars['Length'].mean())
cars['Height'] = cars['Height'].fillna(cars['Height'].mean())
cars['Width'] = cars['Width'].fillna(cars['Width'].mean())
cars['Displacement'] = cars['Displacement'].fillna(cars['Displacement'].mean())
cars['Wheelbase'] = cars['Wheelbase'].fillna(cars['Wheelbase'].mean())
cars['Fuel_Tank_Capacity'] = cars['Fuel_Tank_Capacity'].fillna(cars['Fuel_Tank_Capacity'].mean())
cars.isnull().sum()
# Out:
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement            0
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 140 entries, Make to Electric_Range
# dtypes: float64(21), int32(1), object(118)
# memory usage: 1.4+ MB

# %%
cars.to_csv("Cleaned_data(1).xls")

# %%
plt.figure(figsize=(20, 10))
sns.pairplot(cars)
plt.show()

# %%
sns.countplot(data=cars, x='Fuel_Type',alpha=.6, color='red')
plt.title('Cars count by engine fuel type',fontsize=18)
plt.xlabel('Fuel Type', fontsize=16)
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.histplot(data=cars, x='Displacement',alpha=.6, color='red')
plt.title('Cars count by displacement',fontsize=18)
plt.xlabel('Displacemnt', fontsize=16)
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.countplot(data=cars, x='Type',alpha=.6, color='red')
plt.title('Cars count bytype',fontsize=18)
plt.xlabel('Fuel Type', fontsize=16)
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(data=cars, x='Displacement', y='Ex-Showroom_Price',hue='Fuel_Type',palette='viridis',alpha=.89, s=120 );
plt.xticks(fontsize=13);
plt.yticks(fontsize=13)
plt.xlabel('Engine Size',fontsize=14)
plt.ylabel('Ex-Showroom_Price',fontsize=14)
plt.title('Engine Size VS Ex-Showroom_Price',fontsize=20);

# %%
plt.figure(figsize=(30,15))
plt.xticks(fontsize=18, rotation=90)
plt.yticks(fontsize=16)
sns.boxenplot(x="Make", y="Ex-Showroom_Price",
              color="cyan",
              scale="linear", data=cars)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Ex-Showroom_Price'>

# %%
table_mpg = cars.copy().groupby('Fuel_Type',as_index=False)['Fuel_Tank_Capacity'].median().sort_values(by='Fuel_Tank_Capacity',ascending=False)
plt.figure(figsize=(10,10))
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
sns.boxplot(x='Fuel_Type', y='Fuel_Tank_Capacity', data=cars, order=table_mpg['Fuel_Type'])
plt.title('MPG by Fuel Type')
plt.show()

# %%
plt.figure(figsize = (14,8))
Fuel_Type_power = sns.violinplot("Fuel_Type", "Power", data=cars,
               palette=["lightblue", "pink"],split = False);
Fuel_Type_power_swarmplot = sns.swarmplot("Fuel_Type", "Power", data=cars, color = "cyan")
plt.title('Fuel_Type vs Power', fontsize = 18)
plt.ylabel('Power ( in hp )', fontsize = 15)
plt.xlabel('Fuel_Type', fontsize = 15)
plt.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 57.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
corr = cars.corr()
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt='.2f', ax=ax);

# %%
Price is highly (positively) correlated with wheelbase, carlength, carwidth, curbweight, enginesize, horsepower.

Price is negatively correlated to symboling, citympg and highwaympg.

This suggest that cars having high mileage may fall in the 'economy' cars category, and are priced lower.

There are many independent variables which are highly correlated: wheelbase, carlength, curbweight, enginesize etc.. all are positively correlated.

# %%
plt.figure(figsize = (16,8))
drivetrain_mileage = sns.barplot(x ='Drivetrain', y='City_Mileage', data=cars)

#Graph title and other titles
plt.title('Drivetrain vs Mileage', fontsize = 18)
plt.ylabel('Mileage ( km per litres)', fontsize = 15)
plt.xlabel('Drivetrain', fontsize = 15)
# Out:
# Text(0.5, 0, 'Drivetrain')

# %%
plt.figure(figsize = (15,10))
cars_pivot = cars.pivot_table(index = 'Type', columns = 'Body_Type', values = 'Cylinders')
sns.heatmap(cars_pivot,cmap = 'coolwarm', linewidth = 4, linecolor = 'white');
plt.title('Heatmap\n', fontsize = 18)
plt.ylabel('Body Type\n', fontsize = 15)
plt.xlabel('Gear Type', fontsize = 15)
plt.tight_layout()

# %%
fig = plt.figure(figsize = (15,15))
df = fig.subplots()
cars.Make.value_counts().plot(ax=df, kind='pie')
plt.show()
print(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c2ed6c796c89> in <module>
#       3 cars.Make.value_counts().plot(ax=df, kind='pie')
#       4 plt.show()
# ----> 5 print(labels)
#
# NameError: name 'labels' is not defined

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=cars, y='Body_Type')
plt.title('Type of Car',fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Count', fontsize=20)
plt.ylabel('Body Type', fontsize=20)
# Out:
# Text(0, 0.5, 'Body Type')

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=cars, x='Displacement', y='Ex-Showroom_Price')
plt.xlabel('City_Mileage',fontsize=18)
plt.ylabel('Ex-Showroom_Price',fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# Out:
# (array([-5.0e+07,  0.0e+00,  5.0e+07,  1.0e+08,  1.5e+08,  2.0e+08,
#          2.5e+08]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.distplot(cars['Wheelbase'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cars['Length'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize = (65,65))
plt.subplot(3,3,1)
sns.boxplot(x = 'Fuel_Type', y = 'Ex-Showroom_Price', data = cars)
plt.subplot(3,3,2)
sns.boxplot(x = 'Seats_Material', y = 'Ex-Showroom_Price', data = cars)
plt.subplot(3,3,3)
sns.boxplot(x = 'Body_Type', y = 'Ex-Showroom_Price', data = cars)
plt.subplot(3,3,4)
sns.boxplot(x = 'Drivetrain', y = 'Ex-Showroom_Price', data = cars)
plt.subplot(3,3,5)
sns.boxplot(x = 'Engine_Location', y = 'Ex-Showroom_Price', data = cars)
plt.subplot(3,3,6)
sns.boxplot(x = 'Fuel_System', y = 'Ex-Showroom_Price', data = cars)

plt.savefig('box.jpg', bbox_inches='tight', dpi=150)

# %%
plt.figure(figsize = (40,20))
sns.boxplot(x = 'Make', y = 'Ex-Showroom_Price', data = cars)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Ex-Showroom_Price'>

# %% [markdown]
# 1.From the price boxplot it is clear that The brands with the most expensive vehicles in the dataset belong to Bmw,Buick,Jaguar and porsche.
# 2. Whereas the lower priced cars belong to chevrolet
# 3. The median price of gas vehicles is lower than that of Diesel Vehicles.
# 4. 75th percentile of standard aspirated vehicles have a price lower than the median price of turbo aspirated vehicles.
# 5. Two and four Door vehicles are almost equally priced. There are however some outliers in the price of
# two-door vehicles.
# 6. Hatchback vehicles have the lowest median price of vehicles in the data set whereas hardtop vehicles have
# the highest median price.
# 7. The price of vehicles with rear placed engines is significantly higher than the price of vehicles with front
# placed engines.
# 8. Almost all vehicles in the dataset have engines placed in the front of the vehicle. However, the price of
# vehicles with rear placed engines is significantly higher than the price of vehicles with front placed engines.
# 9. The median cost of eight cylinder vehicles is higher than other cylinder categories.
# 10. It is clear that vehicles Multi-port Fuel Injection [MPFI] fuelsystem have the highest median price. There are
# also some outliers on the higher price side having MPFI systems.
# 11. Vehicles with OHCV engine type falls under higher price range.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
fig = px.scatter_3d(cars, x='Ex-Showroom_Price', z='', y='Fuel_Type', color='Make',width=800,height=750)
fig.update_layout(showlegend=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-43cbc1d88db1> in <module>
#       1 import plotly.express as px
# ----> 2 fig = px.scatter_3d(cars, x='Ex-Showroom_Price', z='City_Mileage', y='Fuel_Type', color='Make',width=800,height=750)
#       3 fig.update_layout(showlegend=True)
#       4 fig.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_chart_types.py in scatter_3d(data_frame, x, y, z, color, symbol, size, text, hover_name, hover_data, custom_data, error_x, error_x_minus, error_y, error_y_minus, error_z, error_z_minus, animation_frame, animation_group, category_orders, labels, size_max, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, log_x, log_y, log_z, range_x, range_y, range_z, title, template, width, height)
# ...
